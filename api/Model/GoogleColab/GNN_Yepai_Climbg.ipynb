# %% [markdown]
# 1. 📦 Install Required Libraries

# %%
# !pip install networkx
# Out:
# ^C

# %%
# These URLs are matched to Colab's default PyTorch 2.0 and CUDA 11.8
# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-2.0.0+cu118.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-2.0.0+cu118.html
# !pip install -q torch-geometric
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 20.1 MB/s eta 0:00:00

# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
# Out:
# Torch version: 2.6.0+cu124
# CUDA available: True
# CUDA version: 12.4

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-411b897fb98c> in <cell line: 0>()
#       1 from google.colab import files
#       2
# ----> 3 uploaded = files.upload(mini_all_routes.json)  # Upload 'mini_all_routes.json'
#
# NameError: name 'mini_all_routes' is not defined

# %% [markdown]
# 2. 🧱 Build GNN Graphs from JSON

# %%
import torch
from torch_geometric.data import Data
import json

# Define hold types and helper functions
HOLD_TYPES = ['jug', 'crimp', 'sloper', 'pinch', 'edge']
type_to_onehot = {t: [int(i == j) for i in range(len(HOLD_TYPES))] for j, t in enumerate(HOLD_TYPES)}

def encode_grade(grade_str):
    return int(grade_str.replace("V", ""))

def normalize_coord(val, max_val):
    return val / max_val

def is_reachable(h1, h2, threshold=0.15):
    dx = h1["x"] - h2["x"]
    dy = h1["y"] - h2["y"]
    dist = (dx**2 + dy**2) ** 0.5
    return dist < threshold

def route_to_graph(route):
    wall_w = route["wall_width"]
    wall_h = route["wall_height"]
    holds = route["holds"]

    x_list = []
    edge_index = []

    for h in holds:
        x_norm = h["x"] / wall_w
        y_norm = h["y"] / wall_h
        area_norm = (h["width"] * h["height"]) / (wall_w * wall_h)
        type_oh = type_to_onehot.get(h["type"].lower(), [0]*len(HOLD_TYPES))
        x_list.append([x_norm, y_norm, area_norm] + type_oh)

    for i in range(len(holds)):
        for j in range(len(holds)):
            if i != j:
                h1 = {"x": holds[i]["x"] / wall_w, "y": holds[i]["y"] / wall_h}
                h2 = {"x": holds[j]["x"] / wall_w, "y": holds[j]["y"] / wall_h}
                if is_reachable(h1, h2):
                    edge_index.append([i, j])

    x = torch.tensor(x_list, dtype=torch.float)
    edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
    y = torch.tensor([encode_grade(route["grade"])], dtype=torch.long)

    return Data(x=x, edge_index=edge_index, y=y)

# %% [markdown]
# Graphs

# %%
import networkx as nx
import matplotlib.pyplot as plt

def plot_route_graph(data_obj, route_id=None, image_name=None):
    G = nx.DiGraph()

    # Add nodes with (x, y) positions
    for i, node_feat in enumerate(data_obj.x):
        x = node_feat[0].item()
        y = node_feat[1].item()
        G.add_node(i, pos=(x, -y))  # invert y for visual "top-down"

    # Add edges
    edge_list = data_obj.edge_index.t().tolist()
    G.add_edges_from(edge_list)

    # Plot
    pos = nx.get_node_attributes(G, 'pos')
    plt.figure(figsize=(5, 5))
    nx.draw(G, pos, with_labels=True, node_color='skyblue', edge_color='gray', node_size=500, arrows=True)

    # Title
    title = route_id or "Unnamed Route"
    if image_name:
        title += f"\n({image_name})"
    plt.title(title)
    plt.axis("off")
    plt.show()

# %% [markdown]
# 3. 🧪 Load All Route Graphs

# %%
with open("/content/stoneco_all_routesv1.json") as f:
    raw_routes = json.load(f)

graphs = [route_to_graph(r) for r in raw_routes if r["grade"] is not None]
print(f"✅ Loaded {len(graphs)} graphs from JSON")
# Out:
# ✅ Loaded 61 graphs from JSON

# %% [markdown]
# 4. 🧠 Define GNN Model

# %%
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_mean_pool

class RouteGNN(nn.Module):
    def __init__(self, in_channels, hidden_channels, num_classes):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.fc = nn.Linear(hidden_channels, num_classes)

    def forward(self, x, edge_index, batch):
        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv2(x, edge_index))
        x = global_mean_pool(x, batch)
        return self.fc(x)

# %%
# Show first 5 route graphs
for i in range(5):
    graph = graphs[i]
    route_info = raw_routes[i]
    route_id = route_info.get("route_id")
    image_name = route_info.get("image")

    print(f"🔍 Route ID: {route_id}")
    print(f"🖼 Image: {image_name}")
    print(f"#️⃣ Holds: {graph.num_nodes}, 🧗‍♂️ Edges: {graph.num_edges}")
    plot_route_graph(graph, route_id, image_name)
# Out:
# 🔍 Route ID: green_V8-1_green
# 🖼 Image: green_V8-1.jpg
# #️⃣ Holds: 11, 🧗‍♂️ Edges: 10
# 🔍 Route ID: yellow_V0-1_yellow
# 🖼 Image: yellow_V0-1.jpg
# #️⃣ Holds: 16, 🧗‍♂️ Edges: 68
# 🔍 Route ID: blue_V6-1_blue
# 🖼 Image: blue_V6-1.jpg
# #️⃣ Holds: 9, 🧗‍♂️ Edges: 10
# 🔍 Route ID: pink_V9-1_pink
# 🖼 Image: pink_V9-1.jpg
# #️⃣ Holds: 11, 🧗‍♂️ Edges: 14
# 🔍 Route ID: yellow_V0-2_yellow
# 🖼 Image: yellow_V0-2.jpg
# #️⃣ Holds: 15, 🧗‍♂️ Edges: 12

# %% [markdown]
# 5. 🏋️‍♂️ Train the GNN

# %%
from torch_geometric.loader import DataLoader
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(graphs, test_size=0.2, random_state=42)
train_loader = DataLoader(train_data, batch_size=16, shuffle=True)
test_loader = DataLoader(test_data, batch_size=16)

model = RouteGNN(in_channels=8, hidden_channels=64, num_classes=10)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = nn.CrossEntropyLoss()

for epoch in range(700):
    model.train()
    total_loss = 0
    for batch in train_loader:
        optimizer.zero_grad()
        out = model(batch.x, batch.edge_index, batch.batch)
        loss = criterion(out, batch.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f"Epoch {epoch+1}, Loss: {total_loss:.4f}")
# Out:
# Epoch 1, Loss: 6.8228
# Epoch 2, Loss: 6.6159
# Epoch 3, Loss: 6.4439
# Epoch 4, Loss: 6.3932
# Epoch 5, Loss: 6.2870
# Epoch 6, Loss: 6.2011
# Epoch 7, Loss: 6.1227
# Epoch 8, Loss: 5.9850
# Epoch 9, Loss: 5.8773
# Epoch 10, Loss: 5.7649
# Epoch 11, Loss: 5.6225
# Epoch 12, Loss: 5.5017
# Epoch 13, Loss: 5.4189
# Epoch 14, Loss: 5.3126
# Epoch 15, Loss: 5.2543
# Epoch 16, Loss: 5.1830
# Epoch 17, Loss: 5.1135
# Epoch 18, Loss: 5.0787
# Epoch 19, Loss: 4.9616
# Epoch 20, Loss: 5.0045
# Epoch 21, Loss: 4.9153
# Epoch 22, Loss: 4.7954
# Epoch 23, Loss: 4.9964
# Epoch 24, Loss: 4.7541
# Epoch 25, Loss: 4.9308
# Epoch 26, Loss: 4.6144
# Epoch 27, Loss: 4.7366
# Epoch 28, Loss: 4.6084
# Epoch 29, Loss: 4.5778
# Epoch 30, Loss: 4.5131
# Epoch 31, Loss: 4.6024
# Epoch 32, Loss: 4.4674
# Epoch 33, Loss: 4.4198
# Epoch 34, Loss: 4.3423
# Epoch 35, Loss: 4.3184
# Epoch 36, Loss: 4.1786
# Epoch 37, Loss: 4.2111
# Epoch 38, Loss: 4.2219
# Epoch 39, Loss: 4.1564
# Epoch 40, Loss: 4.0879
# Epoch 41, Loss: 4.0708
# Epoch 42, Loss: 3.9279
# Epoch 43, Loss: 3.9816
# Epoch 44, Loss: 3.8811
# Epoch 45, Loss: 3.8640
# Epoch 46, Loss: 3.7855
# Epoch 47, Loss: 3.7085
# Epoch 48, Loss: 3.7876
# Epoch 49, Loss: 3.6059
# Epoch 50, Loss: 3.6263
# Epoch 51, Loss: 3.4752
# Epoch 52, Loss: 3.3695
# Epoch 53, Loss: 3.3252
# Epoch 54, Loss: 3.3184
# Epoch 55, Loss: 3.2317
# Epoch 56, Loss: 3.1287
# Epoch 57, Loss: 3.2763
# Epoch 58, Loss: 3.0008
# Epoch 59, Loss: 2.9831
# Epoch 60, Loss: 2.9261
# Epoch 61, Loss: 2.8865
# Epoch 62, Loss: 2.8176
# Epoch 63, Loss: 2.8400
# Epoch 64, Loss: 2.8413
# Epoch 65, Loss: 2.7101
# Epoch 66, Loss: 2.6512
# Epoch 67, Loss: 2.5911
# Epoch 68, Loss: 2.6137
# Epoch 69, Loss: 2.6092
# Epoch 70, Loss: 2.5183
# Epoch 71, Loss: 2.4254
# Epoch 72, Loss: 2.4572
# Epoch 73, Loss: 2.3039
# Epoch 74, Loss: 2.3075
# Epoch 75, Loss: 2.2681
# Epoch 76, Loss: 2.3092
# Epoch 77, Loss: 2.1859
# Epoch 78, Loss: 2.1008
# Epoch 79, Loss: 2.0710
# Epoch 80, Loss: 1.9722
# Epoch 81, Loss: 1.9569
# Epoch 82, Loss: 1.8595
# Epoch 83, Loss: 1.8338
# Epoch 84, Loss: 1.8204
# Epoch 85, Loss: 1.8797
# Epoch 86, Loss: 1.7148
# Epoch 87, Loss: 1.8174
# Epoch 88, Loss: 1.6578
# Epoch 89, Loss: 1.6992
# Epoch 90, Loss: 1.6864
# Epoch 91, Loss: 1.6028
# Epoch 92, Loss: 1.5933
# Epoch 93, Loss: 1.4597
# Epoch 94, Loss: 1.5048
# Epoch 95, Loss: 1.3747
# Epoch 96, Loss: 1.4589
# Epoch 97, Loss: 1.4364
# Epoch 98, Loss: 1.3413
# Epoch 99, Loss: 1.3762
# Epoch 100, Loss: 1.3421
# Epoch 101, Loss: 1.3073
# Epoch 102, Loss: 1.1793
# Epoch 103, Loss: 1.2226
# Epoch 104, Loss: 1.1489
# Epoch 105, Loss: 1.1191
# Epoch 106, Loss: 1.1068
# Epoch 107, Loss: 1.0742
# Epoch 108, Loss: 1.0306
# Epoch 109, Loss: 1.0637
# Epoch 110, Loss: 0.9585
# Epoch 111, Loss: 0.9848
# Epoch 112, Loss: 0.9144
# Epoch 113, Loss: 0.9344
# Epoch 114, Loss: 0.9161
# Epoch 115, Loss: 0.9006
# Epoch 116, Loss: 0.9569
# Epoch 117, Loss: 0.9427
# Epoch 118, Loss: 0.8373
# Epoch 119, Loss: 0.8161
# Epoch 120, Loss: 0.7824
# Epoch 121, Loss: 0.7780
# Epoch 122, Loss: 0.7253
# Epoch 123, Loss: 0.7495
# Epoch 124, Loss: 0.7165
# Epoch 125, Loss: 0.6966
# Epoch 126, Loss: 0.7240
# Epoch 127, Loss: 0.6295
# Epoch 128, Loss: 0.6581
# Epoch 129, Loss: 0.6349
# Epoch 130, Loss: 0.6002
# Epoch 131, Loss: 0.5863
# Epoch 132, Loss: 0.6203
# Epoch 133, Loss: 0.5768
# Epoch 134, Loss: 0.5678
# Epoch 135, Loss: 0.5330
# Epoch 136, Loss: 0.5172
# Epoch 137, Loss: 0.5140
# Epoch 138, Loss: 0.5290
# Epoch 139, Loss: 0.6221
# Epoch 140, Loss: 0.5386
# Epoch 141, Loss: 0.4821
# Epoch 142, Loss: 0.4903
# Epoch 143, Loss: 0.4929
# Epoch 144, Loss: 0.4568
# Epoch 145, Loss: 0.4386
# Epoch 146, Loss: 0.4221
# Epoch 147, Loss: 0.3966
# Epoch 148, Loss: 0.3966
# Epoch 149, Loss: 0.3908
# Epoch 150, Loss: 0.3770
# Epoch 151, Loss: 0.3784
# Epoch 152, Loss: 0.3585
# Epoch 153, Loss: 0.3611
# Epoch 154, Loss: 0.3504
# Epoch 155, Loss: 0.3584
# Epoch 156, Loss: 0.3300
# Epoch 157, Loss: 0.3405
# Epoch 158, Loss: 0.3331
# Epoch 159, Loss: 0.3362
# Epoch 160, Loss: 0.3041
# Epoch 161, Loss: 0.3225
# Epoch 162, Loss: 0.2761
# Epoch 163, Loss: 0.2919
# Epoch 164, Loss: 0.2661
# Epoch 165, Loss: 0.3033
# Epoch 166, Loss: 0.2598
# Epoch 167, Loss: 0.3045
# Epoch 168, Loss: 0.2617
# Epoch 169, Loss: 0.2527
# Epoch 170, Loss: 0.2541
# Epoch 171, Loss: 0.2347
# Epoch 172, Loss: 0.2721
# Epoch 173, Loss: 0.2323
# Epoch 174, Loss: 0.2488
# Epoch 175, Loss: 0.2621
# Epoch 176, Loss: 0.2446
# Epoch 177, Loss: 0.2349
# Epoch 178, Loss: 0.1972
# Epoch 179, Loss: 0.2141
# Epoch 180, Loss: 0.1975
# Epoch 181, Loss: 0.2019
# Epoch 182, Loss: 0.2329
# Epoch 183, Loss: 0.1782
# Epoch 184, Loss: 0.2387
# Epoch 185, Loss: 0.1835
# Epoch 186, Loss: 0.2123
# Epoch 187, Loss: 0.2086
# Epoch 188, Loss: 0.1889
# Epoch 189, Loss: 0.1932
# Epoch 190, Loss: 0.1796
# Epoch 191, Loss: 0.1666
# Epoch 192, Loss: 0.1598
# Epoch 193, Loss: 0.1600
# Epoch 194, Loss: 0.1719
# Epoch 195, Loss: 0.1610
# Epoch 196, Loss: 0.1774
# Epoch 197, Loss: 0.1488
# Epoch 198, Loss: 0.1584
# Epoch 199, Loss: 0.1729
# Epoch 200, Loss: 0.1520
# Epoch 201, Loss: 0.1672
# Epoch 202, Loss: 0.1583
# Epoch 203, Loss: 0.1597
# Epoch 204, Loss: 0.1505
# Epoch 205, Loss: 0.1400
# Epoch 206, Loss: 0.1313
# Epoch 207, Loss: 0.1265
# Epoch 208, Loss: 0.1228
# Epoch 209, Loss: 0.1192
# Epoch 210, Loss: 0.1151
# Epoch 211, Loss: 0.1158
# Epoch 212, Loss: 0.1114
# Epoch 213, Loss: 0.1091
# Epoch 214, Loss: 0.1107
# Epoch 215, Loss: 0.1077
# Epoch 216, Loss: 0.1031
# Epoch 217, Loss: 0.1053
# Epoch 218, Loss: 0.1037
# Epoch 219, Loss: 0.1021
# Epoch 220, Loss: 0.1003
# Epoch 221, Loss: 0.0968
# Epoch 222, Loss: 0.0956
# Epoch 223, Loss: 0.0930
# Epoch 224, Loss: 0.0889
# Epoch 225, Loss: 0.0909
# Epoch 226, Loss: 0.0863
# Epoch 227, Loss: 0.0888
# Epoch 228, Loss: 0.0889
# Epoch 229, Loss: 0.0845
# Epoch 230, Loss: 0.0854
# Epoch 231, Loss: 0.0823
# Epoch 232, Loss: 0.0799
# Epoch 233, Loss: 0.0798
# Epoch 234, Loss: 0.0795
# Epoch 235, Loss: 0.0780
# Epoch 236, Loss: 0.0743
# Epoch 237, Loss: 0.0748
# Epoch 238, Loss: 0.0740
# Epoch 239, Loss: 0.0730
# Epoch 240, Loss: 0.0727
# Epoch 241, Loss: 0.0707
# Epoch 242, Loss: 0.0731
# Epoch 243, Loss: 0.0703
# Epoch 244, Loss: 0.0679
# Epoch 245, Loss: 0.0683
# Epoch 246, Loss: 0.0664
# Epoch 247, Loss: 0.0645
# Epoch 248, Loss: 0.0640
# Epoch 249, Loss: 0.0638
# Epoch 250, Loss: 0.0636
# Epoch 251, Loss: 0.0633
# Epoch 252, Loss: 0.0636
# Epoch 253, Loss: 0.0612
# Epoch 254, Loss: 0.0624
# Epoch 255, Loss: 0.0603
# Epoch 256, Loss: 0.0624
# Epoch 257, Loss: 0.0585
# Epoch 258, Loss: 0.0598
# Epoch 259, Loss: 0.0595
# Epoch 260, Loss: 0.0570
# Epoch 261, Loss: 0.0548
# Epoch 262, Loss: 0.0560
# Epoch 263, Loss: 0.0547
# Epoch 264, Loss: 0.0534
# Epoch 265, Loss: 0.0548
# Epoch 266, Loss: 0.0522
# Epoch 267, Loss: 0.0519
# Epoch 268, Loss: 0.0521
# Epoch 269, Loss: 0.0504
# Epoch 270, Loss: 0.0504
# Epoch 271, Loss: 0.0504
# Epoch 272, Loss: 0.0501
# Epoch 273, Loss: 0.0508
# Epoch 274, Loss: 0.0495
# Epoch 275, Loss: 0.0470
# Epoch 276, Loss: 0.0481
# Epoch 277, Loss: 0.0470
# Epoch 278, Loss: 0.0473
# Epoch 279, Loss: 0.0460
# Epoch 280, Loss: 0.0447
# Epoch 281, Loss: 0.0450
# Epoch 282, Loss: 0.0453
# Epoch 283, Loss: 0.0448
# Epoch 284, Loss: 0.0439
# Epoch 285, Loss: 0.0442
# Epoch 286, Loss: 0.0422
# Epoch 287, Loss: 0.0421
# Epoch 288, Loss: 0.0421
# Epoch 289, Loss: 0.0414
# Epoch 290, Loss: 0.0402
# Epoch 291, Loss: 0.0403
# Epoch 292, Loss: 0.0402
# Epoch 293, Loss: 0.0391
# Epoch 294, Loss: 0.0398
# Epoch 295, Loss: 0.0385
# Epoch 296, Loss: 0.0387
# Epoch 297, Loss: 0.0379
# Epoch 298, Loss: 0.0375
# Epoch 299, Loss: 0.0374
# Epoch 300, Loss: 0.0368
# Epoch 301, Loss: 0.0372
# Epoch 302, Loss: 0.0362
# Epoch 303, Loss: 0.0359
# Epoch 304, Loss: 0.0359
# Epoch 305, Loss: 0.0357
# Epoch 306, Loss: 0.0343
# Epoch 307, Loss: 0.0346
# Epoch 308, Loss: 0.0342
# Epoch 309, Loss: 0.0340
# Epoch 310, Loss: 0.0339
# Epoch 311, Loss: 0.0345
# Epoch 312, Loss: 0.0338
# Epoch 313, Loss: 0.0325
# Epoch 314, Loss: 0.0324
# Epoch 315, Loss: 0.0331
# Epoch 316, Loss: 0.0323
# Epoch 317, Loss: 0.0319
# Epoch 318, Loss: 0.0315
# Epoch 319, Loss: 0.0309
# Epoch 320, Loss: 0.0306
# Epoch 321, Loss: 0.0304
# Epoch 322, Loss: 0.0299
# Epoch 323, Loss: 0.0300
# Epoch 324, Loss: 0.0295
# Epoch 325, Loss: 0.0298
# Epoch 326, Loss: 0.0291
# Epoch 327, Loss: 0.0291
# Epoch 328, Loss: 0.0287
# Epoch 329, Loss: 0.0289
# Epoch 330, Loss: 0.0287
# Epoch 331, Loss: 0.0277
# Epoch 332, Loss: 0.0282
# Epoch 333, Loss: 0.0277
# Epoch 334, Loss: 0.0276
# Epoch 335, Loss: 0.0269
# Epoch 336, Loss: 0.0275
# Epoch 337, Loss: 0.0265
# Epoch 338, Loss: 0.0261
# Epoch 339, Loss: 0.0267
# Epoch 340, Loss: 0.0258
# Epoch 341, Loss: 0.0256
# Epoch 342, Loss: 0.0260
# Epoch 343, Loss: 0.0258
# Epoch 344, Loss: 0.0249
# Epoch 345, Loss: 0.0250
# Epoch 346, Loss: 0.0250
# Epoch 347, Loss: 0.0245
# Epoch 348, Loss: 0.0247
# Epoch 349, Loss: 0.0241
# Epoch 350, Loss: 0.0243
# Epoch 351, Loss: 0.0236
# Epoch 352, Loss: 0.0239
# Epoch 353, Loss: 0.0234
# Epoch 354, Loss: 0.0231
# Epoch 355, Loss: 0.0232
# Epoch 356, Loss: 0.0230
# Epoch 357, Loss: 0.0226
# Epoch 358, Loss: 0.0225
# Epoch 359, Loss: 0.0233
# Epoch 360, Loss: 0.0223
# Epoch 361, Loss: 0.0220
# Epoch 362, Loss: 0.0226
# Epoch 363, Loss: 0.0218
# Epoch 364, Loss: 0.0218
# Epoch 365, Loss: 0.0219
# Epoch 366, Loss: 0.0222
# Epoch 367, Loss: 0.0215
# Epoch 368, Loss: 0.0209
# Epoch 369, Loss: 0.0206
# Epoch 370, Loss: 0.0209
# Epoch 371, Loss: 0.0209
# Epoch 372, Loss: 0.0203
# Epoch 373, Loss: 0.0202
# Epoch 374, Loss: 0.0200
# Epoch 375, Loss: 0.0197
# Epoch 376, Loss: 0.0198
# Epoch 377, Loss: 0.0199
# Epoch 378, Loss: 0.0195
# Epoch 379, Loss: 0.0193
# Epoch 380, Loss: 0.0195
# Epoch 381, Loss: 0.0192
# Epoch 382, Loss: 0.0188
# Epoch 383, Loss: 0.0187
# Epoch 384, Loss: 0.0188
# Epoch 385, Loss: 0.0185
# Epoch 386, Loss: 0.0186
# Epoch 387, Loss: 0.0186
# Epoch 388, Loss: 0.0181
# Epoch 389, Loss: 0.0180
# Epoch 390, Loss: 0.0177
# Epoch 391, Loss: 0.0178
# Epoch 392, Loss: 0.0176
# Epoch 393, Loss: 0.0174
# Epoch 394, Loss: 0.0173
# Epoch 395, Loss: 0.0172
# Epoch 396, Loss: 0.0171
# Epoch 397, Loss: 0.0171
# Epoch 398, Loss: 0.0169
# Epoch 399, Loss: 0.0168
# Epoch 400, Loss: 0.0167
# Epoch 401, Loss: 0.0164
# Epoch 402, Loss: 0.0164
# Epoch 403, Loss: 0.0162
# Epoch 404, Loss: 0.0164
# Epoch 405, Loss: 0.0161
# Epoch 406, Loss: 0.0159
# Epoch 407, Loss: 0.0158
# Epoch 408, Loss: 0.0157
# Epoch 409, Loss: 0.0157
# Epoch 410, Loss: 0.0155
# Epoch 411, Loss: 0.0156
# Epoch 412, Loss: 0.0153
# Epoch 413, Loss: 0.0154
# Epoch 414, Loss: 0.0153
# Epoch 415, Loss: 0.0149
# Epoch 416, Loss: 0.0150
# Epoch 417, Loss: 0.0148
# Epoch 418, Loss: 0.0147
# Epoch 419, Loss: 0.0147
# Epoch 420, Loss: 0.0145
# Epoch 421, Loss: 0.0146
# Epoch 422, Loss: 0.0145
# Epoch 423, Loss: 0.0143
# Epoch 424, Loss: 0.0150
# Epoch 425, Loss: 0.0142
# Epoch 426, Loss: 0.0142
# Epoch 427, Loss: 0.0141
# Epoch 428, Loss: 0.0137
# Epoch 429, Loss: 0.0138
# Epoch 430, Loss: 0.0138
# Epoch 431, Loss: 0.0137
# Epoch 432, Loss: 0.0135
# Epoch 433, Loss: 0.0133
# Epoch 434, Loss: 0.0133
# Epoch 435, Loss: 0.0132
# Epoch 436, Loss: 0.0134
# Epoch 437, Loss: 0.0133
# Epoch 438, Loss: 0.0130
# Epoch 439, Loss: 0.0131
# Epoch 440, Loss: 0.0128
# Epoch 441, Loss: 0.0128
# Epoch 442, Loss: 0.0127
# Epoch 443, Loss: 0.0125
# Epoch 444, Loss: 0.0125
# Epoch 445, Loss: 0.0125
# Epoch 446, Loss: 0.0124
# Epoch 447, Loss: 0.0123
# Epoch 448, Loss: 0.0123
# Epoch 449, Loss: 0.0123
# Epoch 450, Loss: 0.0121
# Epoch 451, Loss: 0.0120
# Epoch 452, Loss: 0.0120
# Epoch 453, Loss: 0.0118
# Epoch 454, Loss: 0.0119
# Epoch 455, Loss: 0.0119
# Epoch 456, Loss: 0.0117
# Epoch 457, Loss: 0.0117
# Epoch 458, Loss: 0.0116
# Epoch 459, Loss: 0.0114
# Epoch 460, Loss: 0.0114
# Epoch 461, Loss: 0.0113
# Epoch 462, Loss: 0.0114
# Epoch 463, Loss: 0.0112
# Epoch 464, Loss: 0.0112
# Epoch 465, Loss: 0.0111
# Epoch 466, Loss: 0.0111
# Epoch 467, Loss: 0.0110
# Epoch 468, Loss: 0.0109
# Epoch 469, Loss: 0.0109
# Epoch 470, Loss: 0.0107
# Epoch 471, Loss: 0.0107
# Epoch 472, Loss: 0.0106
# Epoch 473, Loss: 0.0106
# Epoch 474, Loss: 0.0105
# Epoch 475, Loss: 0.0105
# Epoch 476, Loss: 0.0104
# Epoch 477, Loss: 0.0105
# Epoch 478, Loss: 0.0104
# Epoch 479, Loss: 0.0102
# Epoch 480, Loss: 0.0102
# Epoch 481, Loss: 0.0102
# Epoch 482, Loss: 0.0100
# Epoch 483, Loss: 0.0101
# Epoch 484, Loss: 0.0100
# Epoch 485, Loss: 0.0099
# Epoch 486, Loss: 0.0099
# Epoch 487, Loss: 0.0098
# Epoch 488, Loss: 0.0098
# Epoch 489, Loss: 0.0097
# Epoch 490, Loss: 0.0097
# Epoch 491, Loss: 0.0096
# Epoch 492, Loss: 0.0095
# Epoch 493, Loss: 0.0097
# Epoch 494, Loss: 0.0095
# Epoch 495, Loss: 0.0096
# Epoch 496, Loss: 0.0095
# Epoch 497, Loss: 0.0093
# Epoch 498, Loss: 0.0092
# Epoch 499, Loss: 0.0093
# Epoch 500, Loss: 0.0092
# Epoch 501, Loss: 0.0092
# Epoch 502, Loss: 0.0091
# Epoch 503, Loss: 0.0094
# Epoch 504, Loss: 0.0090
# Epoch 505, Loss: 0.0090
# Epoch 506, Loss: 0.0089
# Epoch 507, Loss: 0.0088
# Epoch 508, Loss: 0.0088
# Epoch 509, Loss: 0.0087
# Epoch 510, Loss: 0.0087
# Epoch 511, Loss: 0.0086
# Epoch 512, Loss: 0.0086
# Epoch 513, Loss: 0.0085
# Epoch 514, Loss: 0.0085
# Epoch 515, Loss: 0.0085
# Epoch 516, Loss: 0.0085
# Epoch 517, Loss: 0.0085
# Epoch 518, Loss: 0.0083
# Epoch 519, Loss: 0.0083
# Epoch 520, Loss: 0.0083
# Epoch 521, Loss: 0.0082
# Epoch 522, Loss: 0.0081
# Epoch 523, Loss: 0.0081
# Epoch 524, Loss: 0.0081
# Epoch 525, Loss: 0.0081
# Epoch 526, Loss: 0.0080
# Epoch 527, Loss: 0.0080
# Epoch 528, Loss: 0.0081
# Epoch 529, Loss: 0.0079
# Epoch 530, Loss: 0.0079
# Epoch 531, Loss: 0.0078
# Epoch 532, Loss: 0.0078
# Epoch 533, Loss: 0.0078
# Epoch 534, Loss: 0.0077
# Epoch 535, Loss: 0.0078
# Epoch 536, Loss: 0.0076
# Epoch 537, Loss: 0.0077
# Epoch 538, Loss: 0.0076
# Epoch 539, Loss: 0.0075
# Epoch 540, Loss: 0.0075
# Epoch 541, Loss: 0.0075
# Epoch 542, Loss: 0.0075
# Epoch 543, Loss: 0.0074
# Epoch 544, Loss: 0.0074
# Epoch 545, Loss: 0.0073
# Epoch 546, Loss: 0.0073
# Epoch 547, Loss: 0.0072
# Epoch 548, Loss: 0.0073
# Epoch 549, Loss: 0.0072
# Epoch 550, Loss: 0.0071
# Epoch 551, Loss: 0.0072
# Epoch 552, Loss: 0.0071
# Epoch 553, Loss: 0.0071
# Epoch 554, Loss: 0.0070
# Epoch 555, Loss: 0.0070
# Epoch 556, Loss: 0.0069
# Epoch 557, Loss: 0.0070
# Epoch 558, Loss: 0.0069
# Epoch 559, Loss: 0.0069
# Epoch 560, Loss: 0.0069
# Epoch 561, Loss: 0.0068
# Epoch 562, Loss: 0.0069
# Epoch 563, Loss: 0.0067
# Epoch 564, Loss: 0.0067
# Epoch 565, Loss: 0.0067
# Epoch 566, Loss: 0.0067
# Epoch 567, Loss: 0.0068
# Epoch 568, Loss: 0.0066
# Epoch 569, Loss: 0.0065
# Epoch 570, Loss: 0.0065
# Epoch 571, Loss: 0.0065
# Epoch 572, Loss: 0.0065
# Epoch 573, Loss: 0.0064
# Epoch 574, Loss: 0.0064
# Epoch 575, Loss: 0.0064
# Epoch 576, Loss: 0.0064
# Epoch 577, Loss: 0.0064
# Epoch 578, Loss: 0.0063
# Epoch 579, Loss: 0.0063
# Epoch 580, Loss: 0.0062
# Epoch 581, Loss: 0.0062
# Epoch 582, Loss: 0.0062
# Epoch 583, Loss: 0.0062
# Epoch 584, Loss: 0.0061
# Epoch 585, Loss: 0.0061
# Epoch 586, Loss: 0.0061
# Epoch 587, Loss: 0.0061
# Epoch 588, Loss: 0.0060
# Epoch 589, Loss: 0.0059
# Epoch 590, Loss: 0.0060
# Epoch 591, Loss: 0.0061
# Epoch 592, Loss: 0.0059
# Epoch 593, Loss: 0.0059
# Epoch 594, Loss: 0.0059
# Epoch 595, Loss: 0.0058
# Epoch 596, Loss: 0.0058
# Epoch 597, Loss: 0.0057
# Epoch 598, Loss: 0.0057
# Epoch 599, Loss: 0.0058
# Epoch 600, Loss: 0.0057
# Epoch 601, Loss: 0.0057
# Epoch 602, Loss: 0.0057
# Epoch 603, Loss: 0.0056
# Epoch 604, Loss: 0.0056
# Epoch 605, Loss: 0.0056
# Epoch 606, Loss: 0.0056
# Epoch 607, Loss: 0.0056
# Epoch 608, Loss: 0.0055
# Epoch 609, Loss: 0.0055
# Epoch 610, Loss: 0.0055
# Epoch 611, Loss: 0.0055
# Epoch 612, Loss: 0.0054
# Epoch 613, Loss: 0.0054
# Epoch 614, Loss: 0.0054
# Epoch 615, Loss: 0.0053
# Epoch 616, Loss: 0.0053
# Epoch 617, Loss: 0.0053
# Epoch 618, Loss: 0.0053
# Epoch 619, Loss: 0.0053
# Epoch 620, Loss: 0.0052
# Epoch 621, Loss: 0.0052
# Epoch 622, Loss: 0.0053
# Epoch 623, Loss: 0.0052
# Epoch 624, Loss: 0.0052
# Epoch 625, Loss: 0.0051
# Epoch 626, Loss: 0.0051
# Epoch 627, Loss: 0.0050
# Epoch 628, Loss: 0.0051
# Epoch 629, Loss: 0.0050
# Epoch 630, Loss: 0.0051
# Epoch 631, Loss: 0.0050
# Epoch 632, Loss: 0.0050
# Epoch 633, Loss: 0.0049
# Epoch 634, Loss: 0.0049
# Epoch 635, Loss: 0.0049
# Epoch 636, Loss: 0.0049
# Epoch 637, Loss: 0.0049
# Epoch 638, Loss: 0.0048
# Epoch 639, Loss: 0.0049
# Epoch 640, Loss: 0.0048
# Epoch 641, Loss: 0.0048
# Epoch 642, Loss: 0.0049
# Epoch 643, Loss: 0.0048
# Epoch 644, Loss: 0.0048
# Epoch 645, Loss: 0.0047
# Epoch 646, Loss: 0.0047
# Epoch 647, Loss: 0.0047
# Epoch 648, Loss: 0.0047
# Epoch 649, Loss: 0.0047
# Epoch 650, Loss: 0.0046
# Epoch 651, Loss: 0.0046
# Epoch 652, Loss: 0.0046
# Epoch 653, Loss: 0.0046
# Epoch 654, Loss: 0.0046
# Epoch 655, Loss: 0.0046
# Epoch 656, Loss: 0.0045
# Epoch 657, Loss: 0.0045
# Epoch 658, Loss: 0.0045
# Epoch 659, Loss: 0.0045
# Epoch 660, Loss: 0.0044
# Epoch 661, Loss: 0.0045
# Epoch 662, Loss: 0.0044
# Epoch 663, Loss: 0.0044
# Epoch 664, Loss: 0.0044
# Epoch 665, Loss: 0.0044
# Epoch 666, Loss: 0.0043
# Epoch 667, Loss: 0.0043
# Epoch 668, Loss: 0.0043
# Epoch 669, Loss: 0.0043
# Epoch 670, Loss: 0.0043
# Epoch 671, Loss: 0.0043
# Epoch 672, Loss: 0.0043
# Epoch 673, Loss: 0.0042
# Epoch 674, Loss: 0.0042
# Epoch 675, Loss: 0.0042
# Epoch 676, Loss: 0.0042
# Epoch 677, Loss: 0.0042
# Epoch 678, Loss: 0.0041
# Epoch 679, Loss: 0.0042
# Epoch 680, Loss: 0.0041
# Epoch 681, Loss: 0.0041
# Epoch 682, Loss: 0.0042
# Epoch 683, Loss: 0.0041
# Epoch 684, Loss: 0.0040
# Epoch 685, Loss: 0.0041
# Epoch 686, Loss: 0.0040
# Epoch 687, Loss: 0.0040
# Epoch 688, Loss: 0.0040
# Epoch 689, Loss: 0.0040
# Epoch 690, Loss: 0.0039
# Epoch 691, Loss: 0.0040
# Epoch 692, Loss: 0.0039
# Epoch 693, Loss: 0.0039
# Epoch 694, Loss: 0.0039
# Epoch 695, Loss: 0.0039
# Epoch 696, Loss: 0.0039
# Epoch 697, Loss: 0.0039
# Epoch 698, Loss: 0.0038
# Epoch 699, Loss: 0.0038
# Epoch 700, Loss: 0.0038

# %% [markdown]
# Evaluate

# %%
def encode_grade(grade_str):
    return int(grade_str.replace("V", ""))

def decode_grade(index):
    return f"V{index}"

model.eval()

correct = 0
total = 0

with torch.no_grad():
    for batch in test_loader:
        out = model(batch.x, batch.edge_index, batch.batch)
        pred = out.argmax(dim=1)

        for p, y in zip(pred, batch.y):
            pred_val = p.item()
            true_val = y.item()
            pred_label = decode_grade(pred_val)
            true_label = decode_grade(true_val)

            is_correct = abs(pred_val - true_val) <= 3
            if is_correct:
                correct += 1
            total += 1

            result_str = "✅ Correct" if is_correct else "❌ Wrong"
            print(f"Predicted: {pred_label}, Actual: {true_label} → {result_str}")

accuracy = correct / total if total > 0 else 0
print(f"\n🎯 Accuracy within ±1 grade: {accuracy:.2%}")
# Out:
# Predicted: V6, Actual: V8 → ✅ Correct
# Predicted: V6, Actual: V2 → ❌ Wrong
# Predicted: V3, Actual: V2 → ✅ Correct
# Predicted: V3, Actual: V6 → ✅ Correct
# Predicted: V3, Actual: V7 → ❌ Wrong
# Predicted: V4, Actual: V7 → ✅ Correct
# Predicted: V0, Actual: V5 → ❌ Wrong
# Predicted: V6, Actual: V2 → ❌ Wrong
# Predicted: V1, Actual: V1 → ✅ Correct
# Predicted: V3, Actual: V6 → ✅ Correct
# Predicted: V9, Actual: V5 → ❌ Wrong
# Predicted: V0, Actual: V4 → ❌ Wrong
# Predicted: V0, Actual: V1 → ✅ Correct
#
# 🎯 Accuracy within ±1 grade: 53.85%

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

y_true = []
y_pred = []

with torch.no_grad():
    for batch in test_loader:
        out = model(batch.x, batch.edge_index, batch.batch)
        pred = out.argmax(dim=1)
        y_true.extend(batch.y.tolist())
        y_pred.extend(pred.tolist())

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %%
torch.save(model.state_dict(), "route_gnn_weights.pth")
